# %% [markdown]
# # TO RUN
# 1. Make sure you installed all the dependencies
# 2. open **'init_notebook.py'** and change the **projectFolder** to the src folder of the repository.
# 3. In the following cell change the dataDir to the data directory of the InD dataset

# %%
# dataDir = "/home/ababil/BUET/AV/Behavior Hypotheses/location-2"
# dataDir = "D:/AV/Code/location-2"
# dataDir = "D:/AV/DataSetExploration/drone-dataset-tools/data/location-2"
# dataDir ="C:/Users/ASUS/Desktop/buetav/behavior-hypotheses-main/location-2"
dataDir = "D:/desktop_alternative/buetav/behavior-hypotheses-main/location-2"

# %%
# exec(open('init_notebook.py').read())
# exec(open('C:/Users/ASUS/Desktop/buetav/behavior-hypotheses-main/src/notebooks/init_notebook.py').read())
exec(open('D:/desktop_alternative/buetav/behavior-hypotheses-main/src/notebooks/init_notebook.py').read())

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np
import sys

from tti_dataset_tools.TrajectoryTransformer import TrajectoryTransformer
from tti_dataset_tools.TrajectoryVisualizer import TrajectoryVisualizer
from tti_dataset_tools.TrajectoryCleaner import TrajectoryCleaner
sys.path.append(os.path.abspath('C:/Users/ASUS/Desktop/buetav/behavior-hypotheses-main/src'))
from behavior_tools.TrajectoryADECalculator import TrajectoryADECalculator

# from behavior_tools.Testing import TrajectoryTestingCalculator
from behavior_tools.Sampler import Sampler
from tti_dataset_tools.ColMapper import ColMapper

# %%
sceneId = 210
date = "2023-05-04"
fps=10
minYDisplacement = 5
maxXDisplacement = 6
pedDf = pd.read_csv(os.path.join(dataDir, f"{date}-fps-{fps}-scene-{sceneId}-pedestrians.csv"))
otherDf = pd.read_csv(os.path.join(dataDir, f"{date}-fps-{fps}-scene-{sceneId}-others.csv"))
tracksMeta = pd.read_csv(os.path.join(dataDir, f"{date}-fps-{fps}-scene-{sceneId}-meta.csv"))

# %%
visualizer = TrajectoryVisualizer()
adeCalculator = TrajectoryADECalculator()
# testingCalculator = TrajectoryTestingCalculator()
colMapper = ColMapper(
        fps=10,
        idCol='uniqueTrackId', 
        xCol='sceneX', 
        yCol='sceneY',
        xVelCol='sceneXVelocity', 
        yVelCol='sceneYVelocity',
        # xAccCol='sceneXAcceleration',
        # yAccCol='sceneYAcceleration',
        speedCol='speed',
        # accelerationCol='acceleration',
    )
transformer = TrajectoryTransformer(colMapper)
cleaner = TrajectoryCleaner(
    colMapper = colMapper,
    minSpeed = 0.0, # we can consider them as obstacles
    maxSpeed = 3.5,
    # minAcceleration = 0.0,
    # maxAcceleration = 2.0,   
    minYDisplacement = minYDisplacement,
    maxXDisplacement = maxXDisplacement
)
transformer.deriveSpeed(pedDf)
transformer.deriveDisplacements(pedDf)
# transformer.deriveAcceleration(pedDf)
# plt.boxplot(pedDf['displacementY'])
# plt.show()
# plt.boxplot(pedDf['speed'])
# plt.show()
# plt.boxplot(pedDf['acceleration'])
# plt.show()

# %%
xCol="sceneX"
yCol="sceneY"
cleanPedDf = cleaner.cleanByYDisplacement(pedDf, byIQR=False)

# visualizer.show(pedDf, idCol = 'uniqueTrackId', xCol = 'sceneX', yCol = 'sceneY')
# visualizer.show(cleanPedDf, idCol = 'uniqueTrackId', xCol = 'sceneX', yCol = 'sceneY')
allPedIds = list(cleanPedDf["uniqueTrackId"].unique())
transformer.translateAllToLocalSource(cleanPedDf)

southIds = []
for pedId in allPedIds:
    trackDf = cleanPedDf[cleanPedDf["uniqueTrackId"] == pedId]
    trackMeta = tracksMeta[tracksMeta["uniqueTrackId"] == pedId].iloc[0]
    # print(trackMeta['verticalDirection'])
    if trackMeta['verticalDirection'] == "SOUTH":
        southIds.append(pedId)
        # print(trackMeta["uniqueTrackId"])
        X, Y = transformer.rotate180(trackDf,xCol,yCol)

        # X, Y = transformer.rotate(trackDf)
        cleanPedDf.loc[cleanPedDf["uniqueTrackId"] == pedId, 'localX'] = X
        cleanPedDf.loc[cleanPedDf["uniqueTrackId"] == pedId, 'localY'] = Y
len(cleanPedDf)
# Out:
# using min Y displacement (5)
# 11101

# %%
startingDf = cleanPedDf[cleanPedDf["displacementY"] < 1].copy()
midDf = cleanPedDf[(cleanPedDf["displacementY"] >= 1) & (cleanPedDf["displacementY"] < 4)].copy()
endDf = cleanPedDf[(cleanPedDf["displacementY"] >= 4)].copy()
startingDf.head(10)
# Out:
#    recordingId  frame  uniqueTrackId  sceneId  roadWidth    sceneX    sceneY  \
# 0           18    750          18023      210        5.0  0.629400  2.454854
# 1           18    752          18023      210        5.0  0.637141  2.358691
# 2           18    754          18023      210        5.0  0.644921  2.261374
# 3           18    756          18023      210        5.0  0.653314  2.163065
# 4           18    758          18023      210        5.0  0.661952  2.065082
# 5           18    760          18023      210        5.0  0.670135  1.967831
# 6           18    762          18023      210        5.0  0.679707  1.870670
# 7           18    764          18023      210        5.0  0.690215  1.773153
# 8           18    766          18023      210        5.0  0.701232  1.674626
# 9           18    768          18023      210        5.0  0.712428  1.575365
#
#    sceneXVelocity  sceneYVelocity  sceneXAcceleration  sceneYAcceleration  \
# 0       -0.047612        0.481508           -0.044860           -0.028943
# 1       -0.038708        0.480816           -0.044520            0.003463
# 2       -0.038896        0.486585            0.000940           -0.028846
# 3       -0.041969        0.491544            0.015368           -0.024797
# 4       -0.043190        0.489915            0.006105            0.008146
# 5       -0.040911        0.486252           -0.011395            0.018314
# 6       -0.047861        0.485808            0.034750            0.002224
# 7       -0.052542        0.487584            0.023403           -0.008883
# 8       -0.055084        0.492634            0.012713           -0.025248
# 9       -0.055981        0.496305            0.004481           -0.018357
#
#       speed  displacementX  displacementY    localX    localY
# 0  0.483857       0.000000       0.000000 -0.629400 -2.454854
# 1  0.482371       0.007742       0.096163 -0.637141 -2.358691
# 2  0.488137       0.015521       0.193480 -0.644921 -2.261374
# 3  0.493333       0.023915       0.291789 -0.653314 -2.163065
# 4  0.491815       0.032553       0.389772 -0.661952 -2.065082
# 5  0.487970       0.040735       0.487023 -0.670135 -1.967831
# 6  0.488159       0.050307       0.584184 -0.679707 -1.870670
# 7  0.490407       0.060815       0.681701 -0.690215 -1.773153
# 8  0.495704       0.071832       0.780228 -0.701232 -1.674626
# 9  0.499452       0.083028       0.879489 -0.712428 -1.575365

# %%
# plt.boxplot(startingDf["speed"])

# %%
# get the pedestrians who started at almost 0 speed.
# get pedestrians who started at almost the median speed.
medianStartingSpeed = startingDf["speed"].median()
medianStartingVelocityDf = startingDf[abs(startingDf["speed"] - medianStartingSpeed) < 0.005].copy()
medianStartingVelocityPedIds = list(medianStartingVelocityDf["uniqueTrackId"].unique())
# medianStartingVelocityPedIds

# %%
allPedIds
startingEditedDf = startingDf[startingDf["uniqueTrackId"] < 18500].copy()
plt.scatter(startingEditedDf["uniqueTrackId"], startingEditedDf["speed"])
# plt.show()
len(allPedIds)
# Out:
# 237

# %%
# plt.scatter(startingEditedDf["displacementY"], startingEditedDf["speed"], marker = ".")


        
# uniqueTrackId_collection = {} 

# for pedId in allPedIds:
#     uniqueTrackId_collection[pedId] = startingEditedDf[startingEditedDf["uniqueTrackId"] == pedId].copy()
#     plt.plot(uniqueTrackId_collection[pedId]["displacementY"], uniqueTrackId_collection[pedId]["speed"])
# # plt.show()
# plt.scatter(startingEditedDf["displacementY"], startingEditedDf["acceleration"], marker = ".")
# for pedId in allPedIds:
#     uniqueTrackId_collection[pedId] = startingEditedDf[startingEditedDf["uniqueTrackId"] == pedId].copy()
#     plt.plot(uniqueTrackId_collection[pedId]["displacementY"], uniqueTrackId_collection[pedId]["acceleration"])
# # plt.show()

# %%
midDf = cleanPedDf[(cleanPedDf["displacementY"] >= 1) & (cleanPedDf["displacementY"] < 4)].copy()
visualizer.show(midDf, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')

# %%
plt.boxplot(midDf["speed"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1df50f033d0>,
#   <matplotlib.lines.Line2D at 0x1df51d72990>],
#  'caps': [<matplotlib.lines.Line2D at 0x1df51d7d610>,
#   <matplotlib.lines.Line2D at 0x1df51d49190>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1df51d9ed90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1df51d49b10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1df51d484d0>],
#  'means': []}

# %%
endDf = cleanPedDf[(cleanPedDf["displacementY"] >= 4)].copy()
visualizer.show(endDf, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')

# %%
plt.boxplot(endDf["speed"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1df517aa350>,
#   <matplotlib.lines.Line2D at 0x1df517aac10>],
#  'caps': [<matplotlib.lines.Line2D at 0x1df517a8c10>,
#   <matplotlib.lines.Line2D at 0x1df517aa5d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1df517aa1d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1df517a9650>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1df513a2990>],
#  'means': []}

# %%
sns.histplot(endDf["speed"])
# Out:
# <AxesSubplot: xlabel='speed', ylabel='Count'>

# %%
trackDf = cleanPedDf[cleanPedDf["uniqueTrackId"]==18023]
ade = adeCalculator.getADE(trackDf, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')
ade
# Out:
# 0.30499600204316435

# %%
aade = adeCalculator.getAADE(startingDf, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')
aade
# Out:
# 0.11113380180375267

# %%
sampler = Sampler()
sampleDf = sampler.getRandom(startingDf, idCol = 'uniqueTrackId', n=10)
aade = adeCalculator.getAADE(sampleDf, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')
aade
# Out:
# 0.18335606180797787

# %%
ades = adeCalculator.getADEs(cleanPedDf, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')

fig, axs = plt.subplots(ncols=3, figsize=(20, 10))
plt.rc('font', size=20)
plt.rc('axes', labelsize=18)

sns.histplot(ades, kde='true', ax=axs[0])
sns.kdeplot(ades, ax=axs[1])
sns.boxplot(ades, ax=axs[2])
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot: >

# %%
ades = adeCalculator.getADEs(startingDf, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')


fig, axs = plt.subplots(ncols=3, figsize=(20, 5))
sns.histplot(ades, kde='true', ax=axs[0])
sns.kdeplot(ades, ax=axs[1])
sns.boxplot(ades, ax=axs[2])
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot: >

# %%
stats.probplot(ades, dist='norm', plot=plt)
population_mean = 0.0

# Perform the one-sample t-test
t_statistic, p_value = stats.ttest_1samp(ades, population_mean)

# Print the results
print("ades mean", np.mean(ades))
print("T-Statistic:", t_statistic)
print("P-Value:", p_value)
# Out:
# ades mean 0.1111338018037527
# T-Statistic: 22.8635106096754
# P-Value: 8.866339896164554e-62

# %%
ades = adeCalculator.getADEs(sampleDf, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')
fig, axs = plt.subplots(ncols=3, figsize=(20, 5))
sns.histplot(ades, kde='true', ax=axs[0])
sns.kdeplot(ades, ax=axs[1])
sns.boxplot(ades, ax=axs[2])
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot: >

# %%
ades = adeCalculator.getADEs(midDf, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')


fig, axs = plt.subplots(ncols=3, figsize=(20, 5))
sns.histplot(ades, kde='true', ax=axs[0])
sns.kdeplot(ades, ax=axs[1])
sns.boxplot(ades, ax=axs[2])
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot: >

# %%
stats.probplot(ades, dist='norm', plot=plt)

print("ades mean", np.mean(ades))
# print(ades)
# aades = np.array(ades)
# mean = np.mean(aades)
# aades = aades - mean
# mean = np.mean(aades)
# print(mean, aades)
ades = np.array(ades)
alpha_value = 0.05

for population_mean in [0.0,0.1, 0.14, 0.2]:
    aades = ades - population_mean
    # t_statistic, p_value = testingCalculator.getTstatistic_pValue_adeslist(aades,0)
    print(f"population mean {population_mean}, T-Statistic: {t_statistic} P-Value: {p_value}")
    # if((t_statistic>0) and ((p_value/2)>alpha_value)):
    #     print("The null hypothesis is rejected")
    # else:
    #     print("The null hypothesis is accepted")
    if (t_statistic < 0):
        print("The null hypothesis is accepted")
    elif (((p_value/2) < alpha_value)):
        print("The null hypothesis is rejected")
    else:
        print("The null hypothesis is accepted")
# Out:
# ades mean 0.33292388130353723
# population mean 0.0, T-Statistic: 22.8635106096754 P-Value: 8.866339896164554e-62
# The null hypothesis is rejected
# population mean 0.1, T-Statistic: 22.8635106096754 P-Value: 8.866339896164554e-62
# The null hypothesis is rejected
# population mean 0.14, T-Statistic: 22.8635106096754 P-Value: 8.866339896164554e-62
# The null hypothesis is rejected
# population mean 0.2, T-Statistic: 22.8635106096754 P-Value: 8.866339896164554e-62
# The null hypothesis is rejected

# %%
# # stats.probplot(ades, dist='norm', plot=plt)
# population_mean = 0.1

# # Perform the one-sample t-test
# t_statistic, p_value = testingCalculator.getTstatistic_pValue_adeslist(ades,population_mean)

# # Print the results
# # print("ades mean", np.mean(ades))
# print("T-Statistic:", t_statistic)
# print("P-Value:", p_value)

# %%
# # stats.probplot(ades, dist='norm', plot=plt)

# population_mean = 0.2

# # Perform the one-sample t-test
# t_statistic, p_value = testingCalculator.getTstatistic_pValue_adeslist(ades,population_mean)

# # Print the results
# # print("ades mean", np.mean(ades))
# print("T-Statistic:", t_statistic)
# print("P-Value:", p_value)

# %%
# # stats.probplot(ades, dist='norm', plot=plt)
# population_mean = 0.3

# # Perform the one-sample t-test
# t_statistic, p_value = testingCalculator.getTstatistic_pValue_adeslist(ades,population_mean)

# # Print the results
# # print("ades mean", np.mean(ades))
# print("T-Statistic:", t_statistic)
# print("P-Value:", p_value)

# %%
# stats.probplot(ades, dist='norm', plot=plt)
population_mean = 0.4

# Perform the one-sample t-test
t_statistic, p_value = testingCalculator.getTstatistic_pValue_adeslist(ades,population_mean)

# Print the results
# print("ades mean", np.mean(ades))
print("T-Statistic:", t_statistic)
print("P-Value:", p_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 5
#       2 population_mean = 0.4
#       4 # Perform the one-sample t-test
# ----> 5 t_statistic, p_value = testingCalculator.getTstatistic_pValue_adeslist(ades,population_mean)
#       7 # Print the results
#       8 # print("ades mean", np.mean(ades))
#       9 print("T-Statistic:", t_statistic)
#
# NameError: name 'testingCalculator' is not defined

# %%
# stats.probplot(ades, dist='norm', plot=plt)
population_mean = 0.5

# Perform the one-sample t-test
t_statistic, p_value = testingCalculator.getTstatistic_pValue_adeslist(ades,population_mean)

# Print the results
# print("ades mean", np.mean(ades))
print("T-Statistic:", t_statistic)
print("P-Value:", p_value)
# Out:
# T-Statistic: -11.398854437286312
# P-Value: 1.0848359470841045e-22

# %%
ades = adeCalculator.getADEs(endDf, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')
fig, axs = plt.subplots(ncols=3, figsize=(20, 5))
sns.histplot(ades, kde='true', ax=axs[0])
sns.kdeplot(ades, ax=axs[1])
sns.boxplot(ades, ax=axs[2])
# Out:
# <AxesSubplot: >

# %%
prevD = 0
for d in range(1, 6):
    tracksDf = cleanPedDf[(cleanPedDf["displacementY"] >= prevD) & (cleanPedDf["displacementY"] < d)].copy()
    prevD = d
    ades = adeCalculator.getADEs(tracksDf, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')
    fig, axs = plt.subplots(ncols=3, figsize=(20, 5))
    sns.histplot(ades, kde='true', ax=axs[0])
    sns.kdeplot(ades, ax=axs[1])
    sns.boxplot(ades, ax=axs[2])

# %%
prevD = 0

fig, axs = plt.subplots(ncols=5, figsize=(20, 5))
for d in range(1, 6):
    tracksDf = cleanPedDf[(cleanPedDf["displacementY"] >= prevD) & (cleanPedDf["displacementY"] < d)].copy()
    prevD = d
    ades = adeCalculator.getADEs(tracksDf, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')
    sns.boxplot(ades, ax=axs[d-1])

# %%
prevD = 0
aades = []
for d in range(1, 6):
    tracksDf = cleanPedDf[(cleanPedDf["displacementY"] >= prevD) & (cleanPedDf["displacementY"] < d)].copy()
    prevD = d
    aades.append(adeCalculator.getAADE(tracksDf, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY'))
    
print(aades)
# sns.barplot(aades)
# Out:
# [0.10923912159320787, 0.0950322179301514, 0.10635226529293768, 0.1186812554248694, 0.14475771067098828]

# %%
visualizer.show(startingDf[startingDf["uniqueTrackId"]==18023], idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')

# %%
# sampleDf1 = sampler.getRandom(startingDf, idCol = 'uniqueTrackId', n=10)
# aade1 = adeCalculator.getAADE(sampleDf1, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')
# ades1 = adeCalculator.getADEs(sampleDf1, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')
# aade1

# %%
# sampleDf2 = sampler.getRandom(startingDf, idCol = 'uniqueTrackId', n=10)
# aade2 = adeCalculator.getAADE(sampleDf2, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')
# ades2 = adeCalculator.getADEs(sampleDf2, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')
# aade2

# %%
# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(ades1, ades2)

# Print the results
print("T-Statistic:", t_statistic)
print("P-Value:", p_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 # Perform independent t-test
# ----> 2 t_statistic, p_value = stats.ttest_ind(ades1, ades2)
#       4 # Print the results
#       5 print("T-Statistic:", t_statistic)
#
# NameError: name 'ades1' is not defined

# %%
t_statistic, p_value = testingCalculator.getT_statistic_p_value(startingDf, idCol = 'uniqueTrackId', xCol = 'localX', yCol = 'localY')
